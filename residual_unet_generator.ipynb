# %% [markdown]
# ## Blocks

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers, Input, Model

def bn_act(x, act=True):
    x = layers.BatchNormalization()(x)
    if act == True:
        x = layers.Activation("relu")(x)
    return x

def conv_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = bn_act(x)
    conv = layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)
    return conv

def stem(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    conv = conv_block(conv, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    
    output = layers.Add()([conv, shortcut])
    return output

def residual_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    res = conv_block(x, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    res = conv_block(res, filters, kernel_size=kernel_size, padding=padding, strides=1)
    
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    
    output = layers.Add()([shortcut, res])
    return output

def upsample_concat_block(x, xskip):
    u = layers.UpSampling2D((2, 2))(x)
    c = layers.Concatenate()([u, xskip])
    return c

# %% [markdown]
# ## ResUNet

# %%
def ResUNet():
    f = [16, 32, 64, 128, 256]
    inputs = layers.Input((224,224,1))
    
    ## Encoder
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides=2)
    e3 = residual_block(e2, f[2], strides=2)
    e4 = residual_block(e3, f[3], strides=2)
    e5 = residual_block(e4, f[4], strides=2)
    
    ## Bridge
    b0 = conv_block(e5, f[4], strides=1)
    b1 = conv_block(b0, f[4], strides=1)
    
    ## Decoder
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])
    
    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])
    
    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])
    
    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])
    
    outputs = layers.Conv2D(1, (1, 1), padding="same", activation="sigmoid")(d4)
    model = Model(inputs, outputs)
    return model

# %%
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = layers.flatten(y_true)
    y_pred_f = layers.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
model = ResUNet()
adam = keras.optimizers.Adam()
model.compile(optimizer=adam, loss=dice_coef_loss, metrics=[dice_coef])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 16  160         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 224, 224, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 16  32          ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 224, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 224, 224, 16  0           ['conv2d_1[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 224, 224, 16  64         ['add[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 224, 224, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 32  4640        ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 32  544         ['add[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 32  9248        ['activation_2[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 112, 112, 32  0           ['batch_normalization_4[0][0]',
#                                 )                                 'conv2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 32  128        ['add_1[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 64)   18496       ['activation_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 64)   2112        ['add_1[0][0]']
#
#  activation_4 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 64)   36928       ['activation_4[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['batch_normalization_7[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 64)  256         ['add_2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  73856       ['activation_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 128)  8320        ['add_2[0][0]']
#
#  activation_6 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_6[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_10[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 128)  512        ['add_3[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 256)  295168      ['activation_7[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 14, 14, 256)  33024       ['add_3[0][0]']
#
#  activation_8 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_8[0][0]']
#
#  add_4 (Add)                    (None, 14, 14, 256)  0           ['batch_normalization_13[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 14, 14, 256)  1024       ['add_4[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 14, 14, 256)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_10[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 28, 28, 256)  0           ['conv2d_16[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 384)  0           ['up_sampling2d[0][0]',
#                                                                   'add_3[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 384)  1536       ['concatenate[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 384)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 256)  884992      ['activation_11[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 256)  98560       ['concatenate[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 256)  590080      ['activation_12[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 256)  0           ['batch_normalization_18[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 56, 56, 256)  0          ['add_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 320)  0           ['up_sampling2d_1[0][0]',
#                                                                   'add_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 56, 56, 320)  1280       ['concatenate_1[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 56, 56, 320)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 56, 56, 128)  368768      ['activation_13[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 56, 56, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  conv2d_22 (Conv2D)             (None, 56, 56, 128)  41088       ['concatenate_1[0][0]']
#
#  activation_14 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 56, 56, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  conv2d_21 (Conv2D)             (None, 56, 56, 128)  147584      ['activation_14[0][0]']
#
#  add_6 (Add)                    (None, 56, 56, 128)  0           ['batch_normalization_21[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 112, 112, 12  0          ['add_6[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 16  0           ['up_sampling2d_2[0][0]',
#                                 0)                                'add_1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 112, 112, 16  640        ['concatenate_2[0][0]']
#  ormalization)                  0)
#
#  activation_15 (Activation)     (None, 112, 112, 16  0           ['batch_normalization_22[0][0]']
#                                 0)
#
#  conv2d_23 (Conv2D)             (None, 112, 112, 64  92224       ['activation_15[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 112, 112, 64  256        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  conv2d_25 (Conv2D)             (None, 112, 112, 64  10304       ['concatenate_2[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 112, 112, 64  0           ['batch_normalization_23[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 112, 112, 64  256        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  conv2d_24 (Conv2D)             (None, 112, 112, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  add_7 (Add)                    (None, 112, 112, 64  0           ['batch_normalization_24[0][0]',
#                                 )                                 'conv2d_24[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 224, 224, 64  0          ['add_7[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 80  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'add[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 224, 224, 80  320        ['concatenate_3[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 224, 224, 80  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 224, 224, 32  23072       ['activation_17[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 224, 224, 32  128        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  conv2d_28 (Conv2D)             (None, 224, 224, 32  2592        ['concatenate_3[0][0]']
#                                 )
#
#  activation_18 (Activation)     (None, 224, 224, 32  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 224, 224, 32  128        ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  conv2d_27 (Conv2D)             (None, 224, 224, 32  9248        ['activation_18[0][0]']
#                                 )
#
#  add_8 (Add)                    (None, 224, 224, 32  0           ['batch_normalization_27[0][0]',
#                                 )                                 'conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 224, 224, 1)  33          ['add_8[0][0]']
#
# ==================================================================================================
# Total params: 4,722,737
# Trainable params: 4,715,441
# Non-trainable params: 7,296
# __________________________________________________________________________________________________
